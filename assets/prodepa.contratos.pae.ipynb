# %%
import pandas as pd

# %%
df = pd.read_csv('prodepa.pae.csv')

# %%
df.head()
# Out:
#    Índice          Nº PAE SISTEMA PAE     ANO         Nº   Origem  \
# 0       1  E-2024/2089227       PAE 4  2024.0  2089227.0  Interna
# 1       2    2020/1067119       PAE 3  2020.0  1067119.0  Interna
# 2       3     2020/230600       PAE 3  2020.0   230600.0  Interna
# 3       4     2020/321489       PAE 3  2020.0   321489.0  Interna
# 4       5     2020/543405       PAE 3  2020.0   543405.0  Interna
#
#           CLIENTE Urgência             Andamento SETOR ATUAL  ...  \
# 0            SEEL      Sim  Em análise comercial         DCO  ...
# 1             TJE      Não         Para execução         DNN  ...
# 2             CCG      Não         Para execução         DNN  ...
# 3         CINBESA      Não         Para execução         DNN  ...
# 4  PREF PRIMAVERA      Não         Para execução         DNN  ...
#
#                                            HISTÓRICO   Analista  \
# 0                          Contrato não foi faturado     Regina
# 1  Contrato com vigência de 4 anos. Não houveram ...      Jesus
# 2                                                NaN  Rocivaldo
# 3                                                NaN    Juliana
# 4                                                NaN     Regina
#
#       VALOR GLOBAL Lei de licitação contMesesContrato Vencimento em dias  \
# 0      R$ 2.956,20           8666.0                12                 32
# 1  R$ 3.404.914,16           8666.0                60                268
# 2      R$ 3.658,92           8666.0                60                  3
# 3    R$ 641.562,24           8666.0                59                 84
# 4      R$ 5.399,25           8666.0                59                 84
#
#    Prazo Renovação (meses) Pode ser renovado? Proposta Comercial Atual  \
# 0                     60.0       pode renovar                 072/2024
# 1                     60.0   não pode renovar                 281/2024
# 2                     60.0   não pode renovar                 088/2024
# 3                     60.0       pode renovar                 138/2024
# 4                     60.0       pode renovar                 106/2024
#
#    TDESK INDEXA
# 0  2.024013e+09
# 1  2.024044e+09
# 2  2.024019e+09
# 3           NaN
# 4           NaN
#
# [5 rows x 32 columns]

# %%
contratos_vencidos = df[df['Vencimento em dias'] == 'vencido']
print(contratos_vencidos)
# Out:
#      Índice          Nº PAE SISTEMA PAE     ANO         Nº   Origem  \
# 5         6     2020/649411       PAE 3  2020.0   649411.0  Interna
# 112     113    2022/1349509       PAE 3  2022.0  1349509.0  Interna
# 118     119    2021/1231811       PAE 3  2021.0  1231811.0  Interna
# 124     125     2023/746191       PAE 3  2023.0   746191.0  Interna
# 125     126  E-2024/2393629       PAE 4  2024.0  2393629.0  Interna
# 126     127  E-2024/2398117       PAE 4  2024.0  2398117.0  Interna
# 132     133    2020/1103005       PAE 3  2020.0  1103005.0  Interna
# 143     144  E-2023/2325952       PAE 4  2023.0  2325952.0  Interna
# 147     148    2022/1617461       PAE 3  2022.0  1617461.0  Interna
# 148     149  E-2025/2076453       PAE 4  2025.0  2076453.0  Interna
# 160     161     2022/155848       PAE 3  2022.0   155848.0  Interna
# 162     163      2022/98219       PAE 3  2022.0    98219.0  Interna
# 164     165     2023/188544       PAE 3  2023.0   188544.0  Interna
# 167     168  E-2024/2032814       PAE 4  2024.0  2032814.0  Interna
#
#                            CLIENTE Urgência              Andamento  \
# 5                            ARCON      Não              Arquivado
# 112  PM SÃO SEBASTIÃO DA BOA VISTA      Sim          Para execução
# 118         FMAS PALESTINA DO PARÁ      Não          Para execução
# 124       PM SANTO ANTONIO DO TAUÁ      Não          Para execução
# 125                         ARTRAN      Não          Para execução
# 126                         ARTRAN      Não          Para execução
# 132                         IGEPPS      Não          Para execução
# 143                          IOEPA      Não          Para execução
# 147                   CODEC-CAZBAR      Não          Para execução
# 148                     IMETROPARA      Sim          Para execução
# 160                        ADEPARÁ      Sim          Em negociação
# 162                           MPCM      Sim              Arquivado
# 164                            CMG      Não  Em tramitação interna
# 167                         SECTET      Não  Em tramitação interna
#
#     SETOR ATUAL  ...                                          HISTÓRICO  \
# 5           DCO  ...  Cliente não irá renovar o contrato que irá pas...
# 112         DNN  ...                                                NaN
# 118         DNN  ...                                                NaN
# 124         DNN  ...                                                NaN
# 125         DNN  ...                                                NaN
# 126         DNN  ...                                                NaN
# 132         DNN  ...                                                NaN
# 143         DNN  ...                                                NaN
# 147         DNN  ...                                                NaN
# 148         DNN  ...                                                NaN
# 160         DCO  ...                                                NaN
# 162         DCO  ...     Prorrogação, reajuste de 4,62% (IPCA DEZ/2023)
# 164         DCO  ...  Proposta não contempla reajuste, cliente envio...
# 167         AJU  ...  Enviado à AJU para analise e assinatura do pre...
#
#       Analista     VALOR GLOBAL Lei de licitação contMesesContrato  \
# 5    Rocivaldo    R$ 138.885,59           8666.0                48
# 112     Regina              NaN           8666.0              1497
# 118     Regina              NaN           8666.0              1497
# 124     Regina              NaN           8666.0              1488
# 125  Rocivaldo              NaN           8666.0                 0
# 126  Rocivaldo              NaN           8666.0                 0
# 132    Juliana     R$ 43.508,88           8666.0                48
# 143      Jesus    R$ 173.904,24           8666.0              1498
# 147     Regina              NaN           8666.0              1499
# 148      Jesus    R$ 197.943,10           8666.0              1500
# 160      Jesus              NaN           8666.0                24
# 162  Rocivaldo     R$ 46.605,20           8666.0                36
# 164  Rocivaldo      R$ 6.875,16           8666.0                23
# 167  Rocivaldo  R$ 2.154.962,35          14133.0                12
#
#     Vencimento em dias  Prazo Renovação (meses)  \
# 5              vencido                     60.0
# 112            vencido                     60.0
# 118            vencido                     60.0
# 124            vencido                     60.0
# 125            vencido                     60.0
# 126            vencido                     60.0
# 132            vencido                     60.0
# 143            vencido                     60.0
# 147            vencido                     60.0
# 148            vencido                     60.0
# 160            vencido                     60.0
# 162            vencido                     60.0
# 164            vencido                     60.0
# 167            vencido                    120.0
#
#                        Pode ser renovado? Proposta Comercial Atual  \
# 5                            pode renovar                 144/2024
# 112  informar data de assinatura original                 236/2024
# 118  informar data de assinatura original                      NaN
# 124  informar data de assinatura original                      NaN
# 125                          pode renovar                 191/2024
# 126                          pode renovar                 192/2024
# 132                          pode renovar                 293/2024
# 143  informar data de assinatura original                 279/2024
# 147  informar data de assinatura original                      NaN
# 148  informar data de assinatura original                      NaN
# 160                          pode renovar                      NaN
# 162                          pode renovar                 016/2024
# 164                          pode renovar                 041/2024
# 167                          pode renovar                 027/2025
#
#      TDESK INDEXA
# 5             NaN
# 112  2.024038e+09
# 118           NaN
# 124           NaN
# 125           NaN
# 126           NaN
# 132           NaN
# 143           NaN
# 147           NaN
# 148           NaN
# 160           NaN
# 162           NaN
# 164           NaN
# 167           NaN
#
# [14 rows x 32 columns]

# %%
df['Andamento'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Andamento'>

# %%
contratos_urgentes =  df[df['Urgência'] == 'Sim']

print(contratos_urgentes)

df['Urgência'].value_counts().plot(kind='bar')
# Out:
#      Índice          Nº PAE SISTEMA PAE     ANO         Nº   Origem  \
# 0         1  E-2024/2089227       PAE 4  2024.0  2089227.0  Interna
# 62       63     2020/587326       PAE 3  2020.0   587326.0  Interna
# 63       64     2024/828364       PAE 3  2024.0   828364.0  Externa
# 64       65    2021/1118418       PAE 3  2021.0  1118418.0  Interna
# 65       66  E-2024/2242461       PAE 4  2024.0  2242461.0  Interna
# 79       80    2022/1181586       PAE 3  2022.0  1181586.0  Interna
# 82       83     2021/975599       PAE 3  2021.0   975599.0  Interna
# 84       85    2022/1221644       PAE 3  2022.0  1221644.0  Interna
# 85       86     2021/915078       PAE 3  2021.0   915078.0  Interna
# 87       88  E-2023/2220123       PAE 4  2023.0  2220123.0  Interna
# 91       92    2022/1177023       PAE 3  2022.0  1177023.0  Interna
# 93       94  E-2024/2336704       PAE 4  2024.0  2336704.0  Interna
# 94       95  E-2024/2336741       PAE 4  2024.0  2336741.0  Interna
# 98       99  E-2024/2360269       PAE 4  2024.0  2360269.0  Interna
# 100     101  E-2023/2265974       PAE 4  2023.0  2265974.0  Interna
# 104     105    2021/1336776       PAE 3  2021.0  1336776.0  Interna
# 105     106  E-2024/2205739       PAE 4  2024.0  2205739.0  Interna
# 106     107    2024/1153813       PAE 3  2024.0  1153813.0  Externa
# 107     108  E-2024/2396566       PAE 4  2024.0  2396566.0  Interna
# 108     109     2020/560329       PAE 3  2020.0   560329.0  Interna
# 111     112    2021/1005824       PAE 3  2021.0  1005824.0  Interna
# 112     113    2022/1349509       PAE 3  2022.0  1349509.0  Interna
# 115     116    2021/1031973       PAE 3  2021.0  1031973.0  Interna
# 123     124       2022/4963       PAE 3  2022.0     4963.0  Interna
# 128     129    2024/1272648       PAE 3  2024.0  1272648.0  Externa
# 131     132  E-2024/2436102       PAE 4  2024.0  2436102.0  Interna
# 134     135     2020/989100       PAE 3  2020.0   989100.0  Interna
# 135     136  E-2024/2452553       PAE 4  2024.0  2452553.0  Interna
# 138     139  E-2023/2330039       PAE 4  2023.0  2330039.0  Interna
# 139     140  E-2024/2525509       PAE 4  2024.0  2525509.0  Interna
# 142     143    2022/1240493       PAE 3  2022.0  1240493.0  Interna
# 146     147    2022/1371592       PAE 3  2022.0  1371592.0  Interna
# 148     149  E-2025/2076453       PAE 4  2025.0  2076453.0  Interna
# 153     154  E-2023/2315966       PAE 4  2023.0  2315966.0  Interna
# 154     155     2022/144408       PAE 3  2022.0   144408.0  Interna
# 156     157    2022/1419591       PAE 3  2022.0  1419591.0  Interna
# 157     158  E-2024/2087501       PAE 4  2024.0  2087501.0  Interna
# 159     160  E-2024/2096604       PAE 4  2024.0  2096604.0  Interna
# 160     161     2022/155848       PAE 3  2022.0   155848.0  Interna
# 161     162  E-2025/2186787       PAE 4  2025.0  2186787.0  Interna
# 162     163      2022/98219       PAE 3  2022.0    98219.0  Interna
# 166     167  E-2024/2054561       PAE 4  2024.0  2054561.0  Interna
# 172     173  E-2024/2030305       PAE 4  2024.0  2030305.0  Interna
# 173     174    2021/1442838       PAE 3  2021.0  1442838.0  Interna
# 174     175     2022/227415       PAE 3  2022.0   227415.0  Interna
#
#                            CLIENTE Urgência  \
# 0                             SEEL      Sim
# 62                           COREN      Sim
# 63                           ARCON      Sim
# 64                           ARCON      Sim
# 65                   PM DOM ELISEU      Sim
# 79                       PM PORTEL      Sim
# 82                      PM BANNACH      Sim
# 84                            SEJU      Sim
# 85                           SETUR      Sim
# 87                         GASPARÁ      Sim
# 91                             MPC      Sim
# 93                             CGE      Sim
# 94                       PM PORTEL      Sim
# 98                          ARTRAN      Sim
# 100                CM MONTE ALEGRE      Sim
# 104                             PC      Sim
# 105                          CEASA      Sim
# 106                           SEAP      Sim
# 107              FMAS RONDONDOPARÁ      Sim
# 108                        PARAPAZ      Sim
# 111          CM CACHOEIRA DO PIRIA      Sim
# 112  PM SÃO SEBASTIÃO DA BOA VISTA      Sim
# 115               FMAS SALINÓPOLIS      Sim
# 123                         HEMOPA      Sim
# 128                         FASEPA      Sim
# 131                           SEAP      Sim
# 134                            CPH      Sim
# 135                           NGPR      Sim
# 138                         FUNSAU      Sim
# 139                            TCE      Sim
# 142                   FMAS PIÇARRA      Sim
# 146                            TRT      Sim
# 148                     IMETROPARA      Sim
# 153                       PARA2000      Sim
# 154                    PMBARCARENA      Sim
# 156                           SEAP      Sim
# 157                   PMSDARAGUAIA      Sim
# 159                         ARTRAN      Sim
# 160                        ADEPARÁ      Sim
# 161                 PM TERRA SANTA      Sim
# 162                           MPCM      Sim
# 166                          SECIR      Sim
# 172                         SEIRDH      Sim
# 173                          ALEPA      Sim
# 174                   CM BARCARENA      Sim
#
#                                         Andamento SETOR ATUAL  ...  \
# 0                            Em análise comercial         DCO  ...
# 62                                  Para execução         DNN  ...
# 63                          Em tramitação interna         DCO  ...
# 64                                  Para execução         DNN  ...
# 65                                  Para execução         DNN  ...
# 79                                      Arquivado         DCO  ...
# 82                                  Para execução         DNN  ...
# 84             Enviado ao cliente para assinatura     CLIENTE  ...
# 85                          Em tramitação interna         AJU  ...
# 87                                  Para execução         DNN  ...
# 91                                  Para execução         DNN  ...
# 93             Enviado ao cliente para assinatura     CLIENTE  ...
# 94                                  Para execução         DNN  ...
# 98                                  Para execução         DNN  ...
# 100                                 Para execução         DNN  ...
# 104                     Manifestação de interesse         DNN  ...
# 105                                 Para execução         DNN  ...
# 106            Enviado ao cliente para assinatura     CLIENTE  ...
# 107                                 Para execução         DNN  ...
# 108                                 Para execução         DNN  ...
# 111  Aguardando correção do contrato pelo cliente         DCO  ...
# 112                                 Para execução         DNN  ...
# 115                                 Para execução         DNN  ...
# 123                                     Arquivado         DCO  ...
# 128            Enviado ao cliente para assinatura         DCO  ...
# 131                                 Para execução         DNN  ...
# 134                         Em tramitação interna         AJU  ...
# 135                         Em tramitação interna         DNN  ...
# 138                                 Para execução         DNN  ...
# 139                                 Para execução         DNN  ...
# 142                         Em tramitação interna         DRI  ...
# 146                         Em tramitação interna         DNN  ...
# 148                                 Para execução         DNN  ...
# 153                                 Para execução         DNN  ...
# 154                         Em tramitação interna         DCO  ...
# 156            Enviado ao cliente para assinatura         DCO  ...
# 157                                 Para execução         DNN  ...
# 159  Aguardando correção do contrato pelo cliente         DCO  ...
# 160                                 Em negociação         DCO  ...
# 161                         Em tramitação interna         DRI  ...
# 162                                     Arquivado         DCO  ...
# 166                                     Arquivado         DNN  ...
# 172            Enviado ao cliente para assinatura         DCO  ...
# 173                         Em tramitação interna         DCO  ...
# 174                         Em tramitação interna         DCO  ...
#
#                                              HISTÓRICO     Analista  \
# 0                            Contrato não foi faturado       Regina
# 62                                                 NaN       Regina
# 63                            PAE INTERNO 2021/1118418        Jesus
# 64   PAE EXTERNO 2024/828364 / AJU tramitou em 19/0...        Jesus
# 65   Já foi feito pagamento parcial (cobrar somente...       Alvaro
# 79                                   Não será renovado       Regina
# 82                                                 NaN       Regina
# 84                                                 NaN    Rocivaldo
# 85                                                 NaN  Pedro Paulo
# 87                                                 NaN      Juliana
# 91                                                 NaN  Pedro Paulo
# 93                                                 NaN  Pedro Paulo
# 94                                                 NaN       Regina
# 98                                                 NaN    Rocivaldo
# 100                                                NaN       Regina
# 104                                                NaN  Pedro Paulo
# 105                                                NaN  Pedro Paulo
# 106                                                NaN  Pedro Paulo
# 107                                                NaN       Regina
# 108                                                NaN  Pedro Paulo
# 111                                                NaN       Regina
# 112                                                NaN       Regina
# 115                                                NaN       Regina
# 123                                                NaN      Juliana
# 128                                                NaN      Juliana
# 131                                                NaN  Pedro Paulo
# 134                                                NaN  Pedro Paulo
# 135                                                NaN      Juliana
# 138                                                NaN  Pedro Paulo
# 139                                                NaN    Rocivaldo
# 142                                                NaN       Regina
# 146                                                NaN        Jesus
# 148                                                NaN        Jesus
# 153                                                NaN    Rocivaldo
# 154                  AGUARDANDO ASSINATURA DO DESPACHO       Regina
# 156  Prorrogação, reajuste de 4,53%, supressão de s...  Pedro Paulo
# 157                                                NaN       Regina
# 159    Prorrogação, reajuste de 6,54% (IGP-M DEZ/2024)    Rocivaldo
# 160                                                NaN        Jesus
# 161              Acesso por 3 meses ao sistema SISPROS       Regina
# 162     Prorrogação, reajuste de 4,62% (IPCA DEZ/2023)    Rocivaldo
# 166          Prorrogação, cliente não aceitou reajuste  Pedro Paulo
# 172                                                NaN    Rocivaldo
# 173                  AGUARDANDO ASSINATURA DO DESPACHO  Pedro Paulo
# 174                                                NaN       Alvaro
#
#       VALOR GLOBAL Lei de licitação            contMesesContrato  \
# 0      R$ 2.956,20           8666.0                           12
# 62             NaN           8666.0  data inicial não fornecida!
# 63             NaN           8666.0  data inicial não fornecida!
# 64             NaN           8666.0  data inicial não fornecida!
# 65             NaN           8666.0  data inicial não fornecida!
# 79             NaN           8666.0  data inicial não fornecida!
# 82             NaN           8666.0  data inicial não fornecida!
# 84             NaN           8666.0  data inicial não fornecida!
# 85             NaN           8666.0  data inicial não fornecida!
# 87             NaN           8666.0  data inicial não fornecida!
# 91             NaN           8666.0  data inicial não fornecida!
# 93             NaN           8666.0  data inicial não fornecida!
# 94             NaN           8666.0  data inicial não fornecida!
# 98             NaN           8666.0  data inicial não fornecida!
# 100            NaN           8666.0  data inicial não fornecida!
# 104            NaN           8666.0  data inicial não fornecida!
# 105            NaN           8666.0  data inicial não fornecida!
# 106            NaN           8666.0  data inicial não fornecida!
# 107            NaN           8666.0  data inicial não fornecida!
# 108            NaN           8666.0  data inicial não fornecida!
# 111            NaN           8666.0  data inicial não fornecida!
# 112            NaN           8666.0                         1497
# 115            NaN           8666.0  data inicial não fornecida!
# 123            NaN           8666.0  data inicial não fornecida!
# 128            NaN           8666.0  data inicial não fornecida!
# 131            NaN           8666.0  data inicial não fornecida!
# 134            NaN           8666.0  data inicial não fornecida!
# 135            NaN           8666.0  data inicial não fornecida!
# 138    R$ 7.864,44           8666.0                           24
# 139   R$ 12.518,91           8666.0                           12
# 142            NaN           8666.0  data inicial não fornecida!
# 146            NaN           8666.0  data inicial não fornecida!
# 148  R$ 197.943,10           8666.0                         1500
# 153  R$ 100.432,20           8666.0                           24
# 154    R$ 5.121,53           8666.0                           48
# 156  R$ 351.987,96           8666.0                           36
# 157    R$ 5.873,13          14133.0                           12
# 159    R$ 7.447,64           8666.0                           25
# 160            NaN           8666.0                           24
# 161   R$ 10.078,87          14133.0                            3
# 162   R$ 46.605,20           8666.0                           36
# 166  R$ 121.657,80          14133.0                           23
# 172    R$ 8.610,72          14133.0                           24
# 173  R$ 468.814,92           8666.0                           53
# 174    R$ 5.084,30           8666.0                           48
#
#                    Vencimento em dias  Prazo Renovação (meses)  \
# 0                                  32                     60.0
# 62   Informar última data de vigência                     60.0
# 63   Informar última data de vigência                     60.0
# 64   Informar última data de vigência                     60.0
# 65   Informar última data de vigência                     60.0
# 79   Informar última data de vigência                     60.0
# 82   Informar última data de vigência                     60.0
# 84   Informar última data de vigência                     60.0
# 85   Informar última data de vigência                     60.0
# 87   Informar última data de vigência                     60.0
# 91   Informar última data de vigência                     60.0
# 93   Informar última data de vigência                     60.0
# 94   Informar última data de vigência                     60.0
# 98   Informar última data de vigência                     60.0
# 100  Informar última data de vigência                     60.0
# 104  Informar última data de vigência                     60.0
# 105  Informar última data de vigência                     60.0
# 106  Informar última data de vigência                     60.0
# 107  Informar última data de vigência                     60.0
# 108  Informar última data de vigência                     60.0
# 111  Informar última data de vigência                     60.0
# 112                           vencido                     60.0
# 115  Informar última data de vigência                     60.0
# 123  Informar última data de vigência                     60.0
# 128  Informar última data de vigência                     60.0
# 131  Informar última data de vigência                     60.0
# 134  Informar última data de vigência                     60.0
# 135  Informar última data de vigência                     60.0
# 138                               286                     60.0
# 139                               279                     60.0
# 142  Informar última data de vigência                     60.0
# 146  Informar última data de vigência                     60.0
# 148                           vencido                     60.0
# 153                               268                     60.0
# 154                               339                     60.0
# 156                               254                     60.0
# 157                               369                    120.0
# 159                               375                     60.0
# 160                           vencido                     60.0
# 161                                59                    120.0
# 162                           vencido                     60.0
# 166                               344                    120.0
# 172                               356                    120.0
# 173                               276                     60.0
# 174                               352                     60.0
#
#                        Pode ser renovado? Proposta Comercial Atual  \
# 0                            pode renovar                 072/2024
# 62   informar data de assinatura original                 190/2024
# 63   informar data de assinatura original                      NaN
# 64   informar data de assinatura original                      NaN
# 65   informar data de assinatura original                      NaN
# 79   informar data de assinatura original                      NaN
# 82   informar data de assinatura original                      NaN
# 84   informar data de assinatura original                      NaN
# 85   informar data de assinatura original                      NaN
# 87   informar data de assinatura original                      NaN
# 91   informar data de assinatura original                      NaN
# 93   informar data de assinatura original                      NaN
# 94   informar data de assinatura original                 213/2024
# 98   informar data de assinatura original                      NaN
# 100                      não pode renovar                      NaN
# 104  informar data de assinatura original                      NaN
# 105                      não pode renovar                      NaN
# 106  informar data de assinatura original                      NaN
# 107  informar data de assinatura original                 218/2024
# 108  informar data de assinatura original                 168/2024
# 111  informar data de assinatura original                      NaN
# 112  informar data de assinatura original                 236/2024
# 115  informar data de assinatura original                 221/2024
# 123  informar data de assinatura original                      NaN
# 128  informar data de assinatura original                 294/2024
# 131  informar data de assinatura original                      NaN
# 134                      não pode renovar                      NaN
# 135  informar data de assinatura original                      NaN
# 138                          pode renovar                 296/2024
# 139                          pode renovar                 260/2024
# 142  informar data de assinatura original                      NaN
# 146  informar data de assinatura original                      NaN
# 148  informar data de assinatura original                      NaN
# 153                          pode renovar                      NaN
# 154                          pode renovar                 002/2025
# 156                          pode renovar                  280/224
# 157                          pode renovar                 051/2025
# 159                          pode renovar                 031/2025
# 160                          pode renovar                      NaN
# 161                          pode renovar                 033/2025
# 162                          pode renovar                 016/2024
# 166                          pode renovar                 008/2025
# 172                          pode renovar                 028/2025
# 173                          pode renovar                 271/2024
# 174                          pode renovar                 271/2025
#
#      TDESK INDEXA
# 0    2.024013e+09
# 62            NaN
# 63            NaN
# 64            NaN
# 65            NaN
# 79            NaN
# 82            NaN
# 84            NaN
# 85            NaN
# 87            NaN
# 91            NaN
# 93            NaN
# 94            NaN
# 98            NaN
# 100           NaN
# 104           NaN
# 105           NaN
# 106           NaN
# 107           NaN
# 108           NaN
# 111           NaN
# 112  2.024038e+09
# 115  2.024037e+09
# 123           NaN
# 128           NaN
# 131           NaN
# 134           NaN
# 135           NaN
# 138  2.025006e+09
# 139           NaN
# 142           NaN
# 146           NaN
# 148           NaN
# 153           NaN
# 154           NaN
# 156  2.025006e+09
# 157           NaN
# 159           NaN
# 160           NaN
# 161           NaN
# 162           NaN
# 166           NaN
# 172           NaN
# 173  2.025006e+09
# 174           NaN
#
# [45 rows x 32 columns]
# <Axes: xlabel='Urgência'>

# %%
df['SETOR ATUAL'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SETOR ATUAL'>

# %%
df['Analista'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Analista'>

# %%
contratos_pae = df['SISTEMA PAE'].value_counts()

print(contratos_pae)

contratos_pae.plot(kind='bar')
# Out:
# SISTEMA PAE
# PAE 3    110
# PAE 4     68
# Name: count, dtype: int64
# <Axes: xlabel='SISTEMA PAE'>
